# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from affinewarp import AffineWarping
model = AffineWarping(np.random.randn(10, 11, 12))

# %%
W = model._warping_matrices()

plt.imshow(W[0])

# %%
plt.plot(model.warping_funcs[0])
