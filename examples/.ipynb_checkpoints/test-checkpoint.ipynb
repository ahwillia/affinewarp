# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# make fake data
def trial(shift=0, noise=.05):
    nt = 100
    t = np.linspace(-20, 20, nt)
    x1 = np.exp(-(t-shift-1)**2)
    x2 = np.exp(-(t-shift+1)**2)
    return np.array([x1, x2]) + noise*np.random.randn(2, nt)

# dataset
ntrials = 99
data = np.array([trial(np.random.uniform(-6, 6)).T for _ in range(ntrials)])

# plot first trial
plt.plot(data[0])
# Out:
# [<matplotlib.lines.Line2D at 0x10f5d7d68>,
#  <matplotlib.lines.Line2D at 0x10f5d7f60>]

# %%
from affinewarp import AffineWarping
model = AffineWarping(data)
plt.plot(data.mean(0))
# Out:
# [<matplotlib.lines.Line2D at 0x1816fa3710>,
#  <matplotlib.lines.Line2D at 0x1816fa3860>]

# %%
model.randfit_warps(iterations=1)
plt.plot(model.fit_template())
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 188.53it/s]
# [<matplotlib.lines.Line2D at 0x1816a33780>,
#  <matplotlib.lines.Line2D at 0x1816a33828>]
